# %%
# Set dependencies
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime

from config import g_key
from config import weather_api_key

# %%
# Generate 2000 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# Get the nearest city using the citipy module.
cities = []
for coordinate in coordinates:
    cities_name = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key


# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# initial counters for log and sets
record_count = 1 
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather['weather'][0]['description']

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | arcata
# Processing Record 2 of Set 1 | kotka
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | provideniya
# Processing Record 5 of Set 1 | pangnirtung
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 1 | san patricio
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | narsaq
# Processing Record 10 of Set 1 | torbay
# Processing Record 11 of Set 1 | awbari
# Processing Record 12 of Set 1 | portland
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | achisay
# City not found. Skipping...
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | lorengau
# Processing Record 18 of Set 1 | farso
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | alofi
# Processing Record 21 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | bambous virieux
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | kodiak
# Processing Record 28 of Set 1 | fairburn
# Processing Record 29 of Set 1 | college
# Processing Record 30 of Set 1 | norman wells
# Processing Record 31 of Set 1 | maningrida
# Processing Record 32 of Set 1 | chapais
# Processing Record 33 of Set 1 | ixtapa
# Processing Record 34 of Set 1 | deh rawud
# City not found. Skipping...
# Processing Record 35 of Set 1 | east london
# Processing Record 36 of Set 1 | chokurdakh
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | lloydminster
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | suining
# Processing Record 43 of Set 1 | atar
# Processing Record 44 of Set 1 | tame
# Processing Record 45 of Set 1 | lompoc
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | ancud
# Processing Record 48 of Set 1 | flinders
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | mehamn
# Processing Record 1 of Set 2 | lasa
# Processing Record 2 of Set 2 | kinshasa
# Processing Record 3 of Set 2 | brae
# Processing Record 4 of Set 2 | butaritari
# Processing Record 5 of Set 2 | nanortalik
# Processing Record 6 of Set 2 | maldonado
# Processing Record 7 of Set 2 | sistranda
# Processing Record 8 of Set 2 | atyrau
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | cherskiy
# Processing Record 12 of Set 2 | rio grande
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | luderitz
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | richards bay
# Processing Record 17 of Set 2 | ahuimanu
# Processing Record 18 of Set 2 | ramnagar
# Processing Record 19 of Set 2 | hithadhoo
# Processing Record 20 of Set 2 | severo-kurilsk
# Processing Record 21 of Set 2 | kwinana
# Processing Record 22 of Set 2 | darlowo
# Processing Record 23 of Set 2 | yei
# Processing Record 24 of Set 2 | nome
# Processing Record 25 of Set 2 | nhulunbuy
# Processing Record 26 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 27 of Set 2 | laguna
# Processing Record 28 of Set 2 | omboue
# Processing Record 29 of Set 2 | patos de minas
# Processing Record 30 of Set 2 | haines junction
# Processing Record 31 of Set 2 | formosa
# Processing Record 32 of Set 2 | tiksi
# Processing Record 33 of Set 2 | cardston
# Processing Record 34 of Set 2 | kruisfontein
# Processing Record 35 of Set 2 | ati
# Processing Record 36 of Set 2 | norfolk
# Processing Record 37 of Set 2 | port-gentil
# Processing Record 38 of Set 2 | malanje
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | francistown
# Processing Record 41 of Set 2 | saint-georges
# Processing Record 42 of Set 2 | poya
# Processing Record 43 of Set 2 | mizdah
# Processing Record 44 of Set 2 | sohag
# Processing Record 45 of Set 2 | carnarvon
# Processing Record 46 of Set 2 | merauke
# Processing Record 47 of Set 2 | steamboat springs
# Processing Record 48 of Set 2 | atuona
# Processing Record 49 of Set 2 | cap malheureux
# Processing Record 50 of Set 2 | dekernes
# Processing Record 1 of Set 3 | vardo
# Processing Record 2 of Set 3 | taoudenni
# Processing Record 3 of Set 3 | hermanus
# Processing Record 4 of Set 3 | hilo
# Processing Record 5 of Set 3 | tomatlan
# Processing Record 6 of Set 3 | tarata
# Processing Record 7 of Set 3 | ajdabiya
# Processing Record 8 of Set 3 | comodoro rivadavia
# Processing Record 9 of Set 3 | lagoa
# Processing Record 10 of Set 3 | jiroft
# City not found. Skipping...
# Processing Record 11 of Set 3 | arraial do cabo
# Processing Record 12 of Set 3 | vanderhoof
# Processing Record 13 of Set 3 | sevierville
# Processing Record 14 of Set 3 | georgetown
# Processing Record 15 of Set 3 | deputatskiy
# Processing Record 16 of Set 3 | brisbane
# Processing Record 17 of Set 3 | marsh harbour
# Processing Record 18 of Set 3 | yulara
# Processing Record 19 of Set 3 | saskylakh
# Processing Record 20 of Set 3 | port alfred
# Processing Record 21 of Set 3 | zhigansk
# Processing Record 22 of Set 3 | harper
# Processing Record 23 of Set 3 | kapaa
# Processing Record 24 of Set 3 | san cristobal
# Processing Record 25 of Set 3 | castro
# Processing Record 26 of Set 3 | tuktoyaktuk
# Processing Record 27 of Set 3 | constitucion
# Processing Record 28 of Set 3 | pereslavl-zalesskiy
# Processing Record 29 of Set 3 | port hedland
# Processing Record 30 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 3 | port elizabeth
# Processing Record 32 of Set 3 | pevek
# Processing Record 33 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 3 | shaoguan
# Processing Record 35 of Set 3 | barrow
# Processing Record 36 of Set 3 | clyde river
# Processing Record 37 of Set 3 | vallenar
# Processing Record 38 of Set 3 | kiama
# Processing Record 39 of Set 3 | elizabethton
# Processing Record 40 of Set 3 | talnakh
# Processing Record 41 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 3 | eregli
# Processing Record 43 of Set 3 | khatanga
# Processing Record 44 of Set 3 | kudahuvadhoo
# Processing Record 45 of Set 3 | bredasdorp
# Processing Record 46 of Set 3 | orange
# Processing Record 47 of Set 3 | knysna
# Processing Record 48 of Set 3 | bethel
# Processing Record 49 of Set 3 | muros
# Processing Record 50 of Set 3 | thompson
# Processing Record 1 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 4 | jiexiu
# Processing Record 3 of Set 4 | namibe
# Processing Record 4 of Set 4 | san roque
# Processing Record 5 of Set 4 | adrar
# Processing Record 6 of Set 4 | rosetta
# Processing Record 7 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 8 of Set 4 | chiredzi
# Processing Record 9 of Set 4 | sorland
# Processing Record 10 of Set 4 | zigong
# Processing Record 11 of Set 4 | longyearbyen
# Processing Record 12 of Set 4 | dandong
# Processing Record 13 of Set 4 | vila do maio
# Processing Record 14 of Set 4 | mar del plata
# Processing Record 15 of Set 4 | souillac
# Processing Record 16 of Set 4 | dingle
# Processing Record 17 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 4 | maniitsoq
# Processing Record 19 of Set 4 | lebu
# Processing Record 20 of Set 4 | bengkulu
# Processing Record 21 of Set 4 | jaguarari
# Processing Record 22 of Set 4 | yinchuan
# Processing Record 23 of Set 4 | shumskiy
# Processing Record 24 of Set 4 | naze
# Processing Record 25 of Set 4 | broome
# Processing Record 26 of Set 4 | waddan
# Processing Record 27 of Set 4 | kharp
# Processing Record 28 of Set 4 | moron
# Processing Record 29 of Set 4 | porto belo
# Processing Record 30 of Set 4 | bathsheba
# Processing Record 31 of Set 4 | chicama
# Processing Record 32 of Set 4 | santiago tuxtla
# Processing Record 33 of Set 4 | bubaque
# Processing Record 34 of Set 4 | noumea
# Processing Record 35 of Set 4 | saint-philippe
# Processing Record 36 of Set 4 | saint george
# Processing Record 37 of Set 4 | nago
# Processing Record 38 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 4 | dzaoudzi
# Processing Record 40 of Set 4 | port shepstone
# Processing Record 41 of Set 4 | pringsewu
# Processing Record 42 of Set 4 | hovd
# Processing Record 43 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 4 | kavieng
# Processing Record 45 of Set 4 | upernavik
# Processing Record 46 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 4 | dubti
# Processing Record 48 of Set 4 | taltal
# Processing Record 49 of Set 4 | broken hill
# Processing Record 50 of Set 4 | tiznit
# Processing Record 1 of Set 5 | aykhal
# Processing Record 2 of Set 5 | koslan
# Processing Record 3 of Set 5 | albino
# Processing Record 4 of Set 5 | filingue
# Processing Record 5 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 5 | kuytun
# Processing Record 7 of Set 5 | trincomalee
# Processing Record 8 of Set 5 | loa janan
# Processing Record 9 of Set 5 | neuquen
# Processing Record 10 of Set 5 | boa vista
# Processing Record 11 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 5 | usinsk
# Processing Record 13 of Set 5 | san jose de guanipa
# Processing Record 14 of Set 5 | labuan
# Processing Record 15 of Set 5 | maracaju
# Processing Record 16 of Set 5 | dicabisagan
# Processing Record 17 of Set 5 | petropolis
# Processing Record 18 of Set 5 | tasiilaq
# Processing Record 19 of Set 5 | linqiong
# Processing Record 20 of Set 5 | faanui
# Processing Record 21 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 5 | trairi
# Processing Record 24 of Set 5 | madras
# Processing Record 25 of Set 5 | takoradi
# Processing Record 26 of Set 5 | airai
# Processing Record 27 of Set 5 | sinnamary
# Processing Record 28 of Set 5 | fershampenuaz
# Processing Record 29 of Set 5 | chino valley
# Processing Record 30 of Set 5 | kaga
# Processing Record 31 of Set 5 | babstovo
# Processing Record 32 of Set 5 | mount gambier
# Processing Record 33 of Set 5 | tuatapere
# Processing Record 34 of Set 5 | okhotsk
# Processing Record 35 of Set 5 | gamba
# Processing Record 36 of Set 5 | weinan
# Processing Record 37 of Set 5 | bagdarin
# Processing Record 38 of Set 5 | kavaratti
# Processing Record 39 of Set 5 | camalu
# Processing Record 40 of Set 5 | maceio
# Processing Record 41 of Set 5 | atchison
# Processing Record 42 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 43 of Set 5 | kilindoni
# Processing Record 44 of Set 5 | agirish
# Processing Record 45 of Set 5 | meadow lake
# Processing Record 46 of Set 5 | puerto baquerizo moreno
# Processing Record 47 of Set 5 | sitka
# Processing Record 48 of Set 5 | bitung
# Processing Record 49 of Set 5 | santa barbara
# Processing Record 50 of Set 5 | nemuro
# Processing Record 1 of Set 6 | russell
# Processing Record 2 of Set 6 | yumen
# Processing Record 3 of Set 6 | pangody
# Processing Record 4 of Set 6 | santa cruz
# Processing Record 5 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 6 | ponta do sol
# Processing Record 7 of Set 6 | andros town
# Processing Record 8 of Set 6 | katsuura
# Processing Record 9 of Set 6 | paso de carrasco
# Processing Record 10 of Set 6 | tokzar
# City not found. Skipping...
# Processing Record 11 of Set 6 | garowe
# Processing Record 12 of Set 6 | umm lajj
# Processing Record 13 of Set 6 | pemangkat
# Processing Record 14 of Set 6 | cockburn town
# Processing Record 15 of Set 6 | auki
# Processing Record 16 of Set 6 | urubicha
# Processing Record 17 of Set 6 | prince rupert
# Processing Record 18 of Set 6 | balaipungut
# Processing Record 19 of Set 6 | sao filipe
# Processing Record 20 of Set 6 | exeter
# Processing Record 21 of Set 6 | carmen
# Processing Record 22 of Set 6 | acandi
# Processing Record 23 of Set 6 | berlevag
# Processing Record 24 of Set 6 | ndele
# Processing Record 25 of Set 6 | santiago del estero
# Processing Record 26 of Set 6 | coihaique
# Processing Record 27 of Set 6 | kieta
# Processing Record 28 of Set 6 | filadelfia
# Processing Record 29 of Set 6 | kattivakkam
# Processing Record 30 of Set 6 | quirinopolis
# Processing Record 31 of Set 6 | gushi
# Processing Record 32 of Set 6 | champerico
# Processing Record 33 of Set 6 | dunedin
# Processing Record 34 of Set 6 | victoria
# Processing Record 35 of Set 6 | mokolo
# Processing Record 36 of Set 6 | moramanga
# Processing Record 37 of Set 6 | mahebourg
# Processing Record 38 of Set 6 | khandyga
# Processing Record 39 of Set 6 | izumo
# Processing Record 40 of Set 6 | paita
# Processing Record 41 of Set 6 | gilbues
# Processing Record 42 of Set 6 | amapa
# Processing Record 43 of Set 6 | lazaro cardenas
# Processing Record 44 of Set 6 | eldorado
# Processing Record 45 of Set 6 | marsa matruh
# Processing Record 46 of Set 6 | kirakira
# Processing Record 47 of Set 6 | esperance
# Processing Record 48 of Set 6 | husavik
# Processing Record 49 of Set 6 | tvedestrand
# Processing Record 50 of Set 6 | saint-augustin
# Processing Record 1 of Set 7 | hun
# Processing Record 2 of Set 7 | vestmannaeyjar
# Processing Record 3 of Set 7 | alihe
# Processing Record 4 of Set 7 | graham
# Processing Record 5 of Set 7 | fujin
# Processing Record 6 of Set 7 | maarianhamina
# Processing Record 7 of Set 7 | honggang
# Processing Record 8 of Set 7 | mitsamiouli
# Processing Record 9 of Set 7 | roma
# Processing Record 10 of Set 7 | barstow
# Processing Record 11 of Set 7 | pokosnoye
# Processing Record 12 of Set 7 | epe
# Processing Record 13 of Set 7 | itarema
# Processing Record 14 of Set 7 | martapura
# Processing Record 15 of Set 7 | marawi
# Processing Record 16 of Set 7 | borgarnes
# Processing Record 17 of Set 7 | vila velha
# Processing Record 18 of Set 7 | donskoye
# Processing Record 19 of Set 7 | maholi
# Processing Record 20 of Set 7 | kupang
# Processing Record 21 of Set 7 | aksu
# Processing Record 22 of Set 7 | sioux lookout
# Processing Record 23 of Set 7 | luwingu
# Processing Record 24 of Set 7 | scarborough
# Processing Record 25 of Set 7 | leningradskiy
# Processing Record 26 of Set 7 | cody
# Processing Record 27 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 28 of Set 7 | bloomingdale
# Processing Record 29 of Set 7 | eureka
# Processing Record 30 of Set 7 | geraldton
# Processing Record 31 of Set 7 | sola
# Processing Record 32 of Set 7 | anadyr
# Processing Record 33 of Set 7 | xingcheng
# Processing Record 34 of Set 7 | sorong
# Processing Record 35 of Set 7 | yar-sale
# Processing Record 36 of Set 7 | avera
# Processing Record 37 of Set 7 | sao joao da barra
# Processing Record 38 of Set 7 | beyneu
# Processing Record 39 of Set 7 | biak
# Processing Record 40 of Set 7 | srednekolymsk
# Processing Record 41 of Set 7 | herndon
# Processing Record 42 of Set 7 | kedougou
# Processing Record 43 of Set 7 | hasaki
# Processing Record 44 of Set 7 | dudinka
# Processing Record 45 of Set 7 | huarmey
# Processing Record 46 of Set 7 | codrington
# Processing Record 47 of Set 7 | paamiut
# Processing Record 48 of Set 7 | qaqortoq
# Processing Record 49 of Set 7 | beba
# Processing Record 50 of Set 7 | mazatlan
# Processing Record 1 of Set 8 | mokhotlong
# Processing Record 2 of Set 8 | ilulissat
# Processing Record 3 of Set 8 | morwa
# Processing Record 4 of Set 8 | sirjan
# Processing Record 5 of Set 8 | valley
# Processing Record 6 of Set 8 | korla
# Processing Record 7 of Set 8 | kuching
# Processing Record 8 of Set 8 | cidreira
# Processing Record 9 of Set 8 | matamoros
# Processing Record 10 of Set 8 | erzin
# Processing Record 11 of Set 8 | port hardy
# Processing Record 12 of Set 8 | tautira
# Processing Record 13 of Set 8 | pangai
# Processing Record 14 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 8 | trenggalek
# Processing Record 16 of Set 8 | polunochnoye
# Processing Record 17 of Set 8 | meulaboh
# Processing Record 18 of Set 8 | bud
# Processing Record 19 of Set 8 | margate
# Processing Record 20 of Set 8 | pershotravneve
# Processing Record 21 of Set 8 | pucallpa
# Processing Record 22 of Set 8 | atambua
# Processing Record 23 of Set 8 | fortuna
# Processing Record 24 of Set 8 | saint pete beach
# Processing Record 25 of Set 8 | nenjiang
# Processing Record 26 of Set 8 | faridpur
# Processing Record 27 of Set 8 | watsa
# Processing Record 28 of Set 8 | nizwa
# Processing Record 29 of Set 8 | mapiri
# Processing Record 30 of Set 8 | mabaruma
# Processing Record 31 of Set 8 | khromtau
# Processing Record 32 of Set 8 | san francisco
# Processing Record 33 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 34 of Set 8 | vila franca do campo
# Processing Record 35 of Set 8 | charyshskoye
# Processing Record 36 of Set 8 | chimbarongo
# Processing Record 37 of Set 8 | luena
# Processing Record 38 of Set 8 | amnat charoen
# Processing Record 39 of Set 8 | shahreza
# Processing Record 40 of Set 8 | tateyama
# Processing Record 41 of Set 8 | santa fe
# Processing Record 42 of Set 8 | shar
# Processing Record 43 of Set 8 | porosozero
# Processing Record 44 of Set 8 | gladstone
# Processing Record 45 of Set 8 | palasbari
# Processing Record 46 of Set 8 | ust-tsilma
# Processing Record 47 of Set 8 | bridlington
# Processing Record 48 of Set 8 | chuy
# Processing Record 49 of Set 8 | the valley
# Processing Record 50 of Set 8 | ankazoabo
# Processing Record 1 of Set 9 | naters
# Processing Record 2 of Set 9 | wote
# Processing Record 3 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 9 | pacific grove
# Processing Record 5 of Set 9 | macapa
# Processing Record 6 of Set 9 | oranjemund
# Processing Record 7 of Set 9 | khani
# Processing Record 8 of Set 9 | xaltianguis
# Processing Record 9 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 10 of Set 9 | maumere
# Processing Record 11 of Set 9 | port lincoln
# Processing Record 12 of Set 9 | tabora
# Processing Record 13 of Set 9 | san pedro
# Processing Record 14 of Set 9 | nizhnyaya salda
# Processing Record 15 of Set 9 | asau
# Processing Record 16 of Set 9 | gualeguay
# Processing Record 17 of Set 9 | mackay
# Processing Record 18 of Set 9 | pitkyaranta
# Processing Record 19 of Set 9 | santa maria
# Processing Record 20 of Set 9 | yeppoon
# Processing Record 21 of Set 9 | hudiksvall
# Processing Record 22 of Set 9 | talcahuano
# Processing Record 23 of Set 9 | bonavista
# Processing Record 24 of Set 9 | saint-pierre
# Processing Record 25 of Set 9 | svetlogorsk
# Processing Record 26 of Set 9 | pervoye maya
# Processing Record 27 of Set 9 | san carlos de bariloche
# Processing Record 28 of Set 9 | sibu
# Processing Record 29 of Set 9 | nelson bay
# Processing Record 30 of Set 9 | benidorm
# Processing Record 31 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 32 of Set 9 | boma
# Processing Record 33 of Set 9 | waipawa
# Processing Record 34 of Set 9 | sembe
# Processing Record 35 of Set 9 | kilemary
# Processing Record 36 of Set 9 | heihe
# Processing Record 37 of Set 9 | tilichiki
# Processing Record 38 of Set 9 | fort wellington
# Processing Record 39 of Set 9 | naron
# Processing Record 40 of Set 9 | kleck
# City not found. Skipping...
# Processing Record 41 of Set 9 | bowen
# Processing Record 42 of Set 9 | kaitangata
# Processing Record 43 of Set 9 | belmonte
# Processing Record 44 of Set 9 | clones
# Processing Record 45 of Set 9 | saldanha
# Processing Record 46 of Set 9 | jining
# Processing Record 47 of Set 9 | hay river
# Processing Record 48 of Set 9 | grand-lahou
# Processing Record 49 of Set 9 | mendi
# Processing Record 50 of Set 9 | bismarck
# Processing Record 1 of Set 10 | batagay-alyta
# Processing Record 2 of Set 10 | banda aceh
# Processing Record 3 of Set 10 | sur
# Processing Record 4 of Set 10 | labytnangi
# Processing Record 5 of Set 10 | lata
# Processing Record 6 of Set 10 | celestun
# Processing Record 7 of Set 10 | along
# Processing Record 8 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 9 of Set 10 | wilmington
# Processing Record 10 of Set 10 | inhambane
# Processing Record 11 of Set 10 | isangel
# Processing Record 12 of Set 10 | vilhena
# Processing Record 13 of Set 10 | shieli
# Processing Record 14 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 10 | qui nhon
# Processing Record 16 of Set 10 | angoram
# Processing Record 17 of Set 10 | whitehorse
# Processing Record 18 of Set 10 | linxia
# Processing Record 19 of Set 10 | esmeraldas
# Processing Record 20 of Set 10 | komsomolskiy
# Processing Record 21 of Set 10 | valdemarpils
# Processing Record 22 of Set 10 | kingman
# Processing Record 23 of Set 10 | linjiang
# Processing Record 24 of Set 10 | myingyan
# Processing Record 25 of Set 10 | cabedelo
# Processing Record 26 of Set 10 | mudyuga
# City not found. Skipping...
# Processing Record 27 of Set 10 | hamilton
# Processing Record 28 of Set 10 | el alto
# Processing Record 29 of Set 10 | adana
# Processing Record 30 of Set 10 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 31 of Set 10 | tura
# Processing Record 32 of Set 10 | zwedru
# Processing Record 33 of Set 10 | camocim
# Processing Record 34 of Set 10 | saint-joseph
# Processing Record 35 of Set 10 | buala
# Processing Record 36 of Set 10 | kingisepp
# Processing Record 37 of Set 10 | morondava
# Processing Record 38 of Set 10 | otradnoye
# Processing Record 39 of Set 10 | popondetta
# Processing Record 40 of Set 10 | necochea
# Processing Record 41 of Set 10 | puerto colombia
# Processing Record 42 of Set 10 | almaty
# Processing Record 43 of Set 10 | kutum
# Processing Record 44 of Set 10 | te anau
# Processing Record 45 of Set 10 | barao de melgaco
# Processing Record 46 of Set 10 | jumla
# Processing Record 47 of Set 10 | alice springs
# Processing Record 48 of Set 10 | karratha
# Processing Record 49 of Set 10 | asfi
# Processing Record 50 of Set 10 | zaysan
# Processing Record 1 of Set 11 | guerrero negro
# Processing Record 2 of Set 11 | benguela
# Processing Record 3 of Set 11 | katrineholm
# Processing Record 4 of Set 11 | coahuayana
# Processing Record 5 of Set 11 | lac du bonnet
# Processing Record 6 of Set 11 | cuauhtemoc
# Processing Record 7 of Set 11 | itoman
# Processing Record 8 of Set 11 | paciran
# Processing Record 9 of Set 11 | toppenish
# Processing Record 10 of Set 11 | kaeng khoi
# Processing Record 11 of Set 11 | tikrit
# Processing Record 12 of Set 11 | sarab
# Processing Record 13 of Set 11 | cayenne
# Processing Record 14 of Set 11 | half moon bay
# Processing Record 15 of Set 11 | skjervoy
# Processing Record 16 of Set 11 | uige
# Processing Record 17 of Set 11 | galle
# Processing Record 18 of Set 11 | lanivtsi
# Processing Record 19 of Set 11 | vanimo
# Processing Record 20 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 11 | thinadhoo
# Processing Record 22 of Set 11 | tabas
# Processing Record 23 of Set 11 | guider
# Processing Record 24 of Set 11 | vostok
# Processing Record 25 of Set 11 | krylovskaya
# Processing Record 26 of Set 11 | baiyin
# Processing Record 27 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 28 of Set 11 | tripoli
# Processing Record 29 of Set 11 | iqaluit
# Processing Record 30 of Set 11 | point fortin
# Processing Record 31 of Set 11 | kishtwar
# Processing Record 32 of Set 11 | ndiekro
# City not found. Skipping...
# Processing Record 33 of Set 11 | krasnaya gora
# Processing Record 34 of Set 11 | inta
# Processing Record 35 of Set 11 | vista hermosa
# Processing Record 36 of Set 11 | lima
# Processing Record 37 of Set 11 | sao felix do xingu
# Processing Record 38 of Set 11 | san andres
# Processing Record 39 of Set 11 | igrim
# Processing Record 40 of Set 11 | godhra
# Processing Record 41 of Set 11 | grindavik
# Processing Record 42 of Set 11 | belyy yar
# Processing Record 43 of Set 11 | nouakchott
# Processing Record 44 of Set 11 | matiri
# Processing Record 45 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 11 | krasnyy chikoy
# Processing Record 47 of Set 11 | san martin
# Processing Record 48 of Set 11 | beaverlodge
# Processing Record 49 of Set 11 | gobabis
# Processing Record 50 of Set 11 | marquette
# Processing Record 1 of Set 12 | luau
# Processing Record 2 of Set 12 | medicine hat
# Processing Record 3 of Set 12 | coquimbo
# Processing Record 4 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 12 | ifanadiana
# Processing Record 6 of Set 12 | egvekinot
# Processing Record 7 of Set 12 | ko samui
# Processing Record 8 of Set 12 | nabire
# Processing Record 9 of Set 12 | luanda
# Processing Record 10 of Set 12 | corralillo
# Processing Record 11 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 12 | leicester
# Processing Record 13 of Set 12 | gorontalo
# Processing Record 14 of Set 12 | pacifica
# Processing Record 15 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 17 of Set 12 | viedma
# Processing Record 18 of Set 12 | mumford
# Processing Record 19 of Set 12 | almaznyy
# Processing Record 20 of Set 12 | bonthe
# Processing Record 21 of Set 12 | mengcheng
# Processing Record 22 of Set 12 | orlik
# Processing Record 23 of Set 12 | monrovia
# Processing Record 24 of Set 12 | cacapava
# Processing Record 25 of Set 12 | salem
# Processing Record 26 of Set 12 | hambantota
# Processing Record 27 of Set 12 | yanchukan
# City not found. Skipping...
# Processing Record 28 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 12 | ferrol
# Processing Record 30 of Set 12 | beshpagir
# Processing Record 31 of Set 12 | dawei
# Processing Record 32 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 33 of Set 12 | matara
# Processing Record 34 of Set 12 | jacareacanga
# Processing Record 35 of Set 12 | mpulungu
# Processing Record 36 of Set 12 | havelock
# Processing Record 37 of Set 12 | rolla
# Processing Record 38 of Set 12 | dapaong
# Processing Record 39 of Set 12 | kijang
# Processing Record 40 of Set 12 | chigore
# Processing Record 41 of Set 12 | pishin
# Processing Record 42 of Set 12 | verkhoyansk
# Processing Record 43 of Set 12 | keti bandar
# Processing Record 44 of Set 12 | sobolevo
# Processing Record 45 of Set 12 | kedrovyy
# Processing Record 46 of Set 12 | phetchaburi
# Processing Record 47 of Set 12 | obo
# Processing Record 48 of Set 12 | minnedosa
# Processing Record 49 of Set 12 | alto araguaia
# Processing Record 50 of Set 12 | kushiro
# Processing Record 1 of Set 13 | eirunepe
# Processing Record 2 of Set 13 | rio verde de mato grosso
# Processing Record 3 of Set 13 | weligama
# Processing Record 4 of Set 13 | urfa
# City not found. Skipping...
# Processing Record 5 of Set 13 | cabo san lucas
# Processing Record 6 of Set 13 | weiser
# Processing Record 7 of Set 13 | salta
# Processing Record 8 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 9 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 10 of Set 13 | senneterre
# Processing Record 11 of Set 13 | los llanos de aridane
# Processing Record 12 of Set 13 | pisco
# Processing Record 13 of Set 13 | kaseda
# Processing Record 14 of Set 13 | laval
# Processing Record 15 of Set 13 | zarate
# Processing Record 16 of Set 13 | touros
# Processing Record 17 of Set 13 | show low
# Processing Record 18 of Set 13 | kalengwa
# Processing Record 19 of Set 13 | brigantine
# Processing Record 20 of Set 13 | young
# Processing Record 21 of Set 13 | tungor
# Processing Record 22 of Set 13 | stamsund
# City not found. Skipping...
# Processing Record 23 of Set 13 | tabuk
# Processing Record 24 of Set 13 | lichinga
# Processing Record 25 of Set 13 | basco
# Processing Record 26 of Set 13 | wajima
# Processing Record 27 of Set 13 | estacion coahuila
# Processing Record 28 of Set 13 | aklavik
# Processing Record 29 of Set 13 | farah
# Processing Record 30 of Set 13 | chalus
# Processing Record 31 of Set 13 | uyovu
# Processing Record 32 of Set 13 | kahului
# Processing Record 33 of Set 13 | tirumullaivasal
# Processing Record 34 of Set 13 | katobu
# Processing Record 35 of Set 13 | ambilobe
# Processing Record 36 of Set 13 | araouane
# Processing Record 37 of Set 13 | nishihara
# Processing Record 38 of Set 13 | la romana
# Processing Record 39 of Set 13 | kyren
# Processing Record 40 of Set 13 | axim
# Processing Record 41 of Set 13 | poddorye
# Processing Record 42 of Set 13 | zaraza
# Processing Record 43 of Set 13 | akdepe
# Processing Record 44 of Set 13 | kadaya
# Processing Record 45 of Set 13 | rawson
# Processing Record 46 of Set 13 | nuuk
# Processing Record 47 of Set 13 | omsukchan
# Processing Record 48 of Set 13 | tual
# Processing Record 49 of Set 13 | saint-denis
# Processing Record 50 of Set 13 | noyabrsk
# Processing Record 1 of Set 14 | la rioja
# Processing Record 2 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 14 | alnashi
# Processing Record 4 of Set 14 | chanika
# Processing Record 5 of Set 14 | shwebo
# Processing Record 6 of Set 14 | goundam
# Processing Record 7 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 14 | mao
# Processing Record 9 of Set 14 | suluova
# Processing Record 10 of Set 14 | millau
# Processing Record 11 of Set 14 | sisimiut
# Processing Record 12 of Set 14 | kisesa
# Processing Record 13 of Set 14 | usogorsk
# Processing Record 14 of Set 14 | baruun-urt
# Processing Record 15 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 16 of Set 14 | kulhudhuffushi
# Processing Record 17 of Set 14 | warrington
# Processing Record 18 of Set 14 | faya
# Processing Record 19 of Set 14 | jalu
# Processing Record 20 of Set 14 | anzio
# Processing Record 21 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 14 | creston
# Processing Record 23 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 14 | barra do garcas
# Processing Record 25 of Set 14 | ust-omchug
# Processing Record 26 of Set 14 | veraval
# Processing Record 27 of Set 14 | ikot ekpene
# Processing Record 28 of Set 14 | warmbad
# Processing Record 29 of Set 14 | navahrudak
# Processing Record 30 of Set 14 | kindersley
# Processing Record 31 of Set 14 | tamale
# Processing Record 32 of Set 14 | umm kaddadah
# Processing Record 33 of Set 14 | gulshat
# City not found. Skipping...
# Processing Record 34 of Set 14 | mkushi
# Processing Record 35 of Set 14 | ondjiva
# Processing Record 36 of Set 14 | krasnoselkup
# Processing Record 37 of Set 14 | olafsvik
# Processing Record 38 of Set 14 | kasamwa
# Processing Record 39 of Set 14 | boende
# Processing Record 40 of Set 14 | gigmoto
# Processing Record 41 of Set 14 | concarneau
# Processing Record 42 of Set 14 | mayo
# Processing Record 43 of Set 14 | padang
# Processing Record 44 of Set 14 | cascais
# Processing Record 45 of Set 14 | simao
# Processing Record 46 of Set 14 | sortland
# Processing Record 47 of Set 14 | tucuma
# Processing Record 48 of Set 14 | evensk
# Processing Record 49 of Set 14 | antalaha
# Processing Record 50 of Set 14 | maubin
# Processing Record 1 of Set 15 | rio gallegos
# Processing Record 2 of Set 15 | cilegon
# Processing Record 3 of Set 15 | pelym
# Processing Record 4 of Set 15 | taybad
# Processing Record 5 of Set 15 | bushehr
# Processing Record 6 of Set 15 | vao
# Processing Record 7 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 8 of Set 15 | kampot
# Processing Record 9 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 15 | la palma
# Processing Record 11 of Set 15 | churapcha
# Processing Record 12 of Set 15 | buin
# Processing Record 13 of Set 15 | lethem
# Processing Record 14 of Set 15 | banjar
# Processing Record 15 of Set 15 | shenjiamen
# Processing Record 16 of Set 15 | banes
# Processing Record 17 of Set 15 | potoci
# Processing Record 18 of Set 15 | oistins
# Processing Record 19 of Set 15 | garden city
# Processing Record 20 of Set 15 | berikulskiy
# City not found. Skipping...
# Processing Record 21 of Set 15 | luganville
# Processing Record 22 of Set 15 | ahipara
# Processing Record 23 of Set 15 | yenagoa
# Processing Record 24 of Set 15 | andapa
# Processing Record 25 of Set 15 | thai binh
# Processing Record 26 of Set 15 | ludvika
# Processing Record 27 of Set 15 | freeport
# Processing Record 28 of Set 15 | yangjiang
# Processing Record 29 of Set 15 | ojinaga
# Processing Record 30 of Set 15 | iquitos
# Processing Record 31 of Set 15 | kindu
# Processing Record 32 of Set 15 | catamarca
# Processing Record 33 of Set 15 | lavrentiya
# Processing Record 34 of Set 15 | balad
# Processing Record 35 of Set 15 | seymchan
# Processing Record 36 of Set 15 | salcedo
# Processing Record 37 of Set 15 | bangassou
# Processing Record 38 of Set 15 | burnie
# Processing Record 39 of Set 15 | port keats
# Processing Record 40 of Set 15 | kholodnyy
# Processing Record 41 of Set 15 | chivay
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 683

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Arcata      US  40.8665 -124.0828     55.92        80          90
# 1         Kotka      FI  60.4664   26.9458     51.06        77          99
# 2   Provideniya      RU  64.3833 -173.3000     35.74        98         100
# 3   Pangnirtung      CA  66.1451  -65.7125     37.40        75          75
# 4  San Patricio      US  28.0170  -97.5169     88.88        37           0
# 5        Albany      US  42.6001  -73.9662     74.68        74           0
# 6        Narsaq      GL  60.9167  -46.0500     48.42        48           8
# 7        Torbay      CA  47.6666  -52.7314     58.75        49          40
# 8        Awbari      LY  26.5921   12.7805     82.06        16           0
# 9      Portland      US  45.5234 -122.6762     53.17        91          90
#
#    Wind Speed Current Description
# 0        0.00     overcast clouds
# 1       18.81     overcast clouds
# 2        7.14     overcast clouds
# 3        3.44       broken clouds
# 4        5.73           clear sky
# 5        0.87           clear sky
# 6        6.82           clear sky
# 7       14.97    scattered clouds
# 8        7.11           clear sky
# 9        1.01                mist

# %%
city_data_df.to_csv(path_or_buf='WeatherPy_Database.csv', index_label="City_ID")
